# %% [markdown]
# # PPO Pendulum-v0 Continuous
#
# Just noticed that I was multiplying ratio with advantage instead of ratio * old policy * advantage since we wanted a change in our policy so may have to look at PPO mountain car again.

# %%
"""Pendulum-v0 PPO continuous"""
"""
This implementation of PPO is based on a2c code with PPO subbed in for actor.
https://spinningup.openai.com/en/latest/algorithms/ppo.html?highlight=ppo


regularization in RL: https://arxiv.org/pdf/1810.00123.pdf
maximum entropy RL: https://medium.com/@awjuliani/maximum-entropy-policies-in-reinforcement-learning-everyday-life-f5a1cc18d32d
add entropy bonus
https://arxiv.org/abs/1704.06440
https://bair.berkeley.edu/blog/2017/10/06/soft-q-learning/

"""

import sys
import gym
import pylab
import numpy as np
from keras.layers import Dense, LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
#from keras import regularizers
from keras import backend as K



EPISODES = 1000
# Out:
# Using TensorFlow backend.

# %%
class PPOAgent:
    def __init__(self, state_size, action_size):
        # if you want to see agent learning, then change to True
        self.render = False
        self.load_model = False
        # get size of state and action
        self.state_size = state_size  # is 4
        self.action_size = action_size  # is 1
        self.value_size = 1  # output size of critic

        # These are hyper parameters for the Policy Gradient
        self.discount_factor = 0.99  # gamma for next state
        self.actor_lr = 0.001 #0.001
        self.critic_lr = 0.003 #0.005

        # old prob before update
        self.old_prob = 0.

        # epsilon value for clipping formula
        self.epsilon = 0.2

        # create models
        self.actor = self.build_actor()
        self.critic = self.build_critic()

        # temp_actor
        self.temp_actor = self.build_actor()

        if self.load_model:
            self.actor.load_weights("./saved_models/my_ppo_pendulum_actor.h5")
            self.critic.load_weights("./saved_models/my_ppo_pendulum_critic.h5")

    # approximate policy and value using Neural Network
    # actor: state is input and probability of each action is output of model (policy)
    def build_actor(self):
        actor = Sequential()
        actor.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        # actor.add(LeakyReLU(alpha=0.1))
        actor.add(Dense(24, activation ='relu', kernel_initializer='he_uniform'))
        actor.add(Dense(self.action_size, activation='tanh',
                        kernel_initializer='he_uniform'))
        actor.summary()
        # See note regarding crossentropy in cartpole_reinforce.py
        actor.compile(loss='mse',
                      optimizer=Adam(lr=self.actor_lr))
        return actor

    # critic: state is input and value of state is output of model
    def build_critic(self):
        critic = Sequential()
        critic.add(Dense(24, input_dim=self.state_size, activation='relu',
                         kernel_initializer='he_uniform'))
        # critic.add(LeakyReLU(alpha=0.1))
        #critic.add(Dense(24, activation='relu', kernel_initializer='he_uniform')) #this layer broke it
        critic.add(Dense(self.value_size, activation='linear',
                         kernel_initializer='he_uniform'))
        critic.summary()
        critic.compile(loss="mse", optimizer=Adam(lr=self.critic_lr))
        return critic

    # flatten the np array of probs
    def actor_action(self, state):
        policy = self.actor.predict(state, batch_size=1).flatten()
        #rescale to [-2, 2]
        policy *= 2
        return policy 

    # get targets and advantages
    def targets_and_adv(self, state, action, reward, next_state, done):
        target = np.zeros((1, self.value_size))  # this is shape (1,1)?
        advantages = np.zeros((1, self.action_size))  # (1,2)

        Svalue = self.critic.predict(state)[0]  # returns an array or tensor so must pick index
        next_Svalue = self.critic.predict(next_state)[0]

        if done:
            # only the chosen action gets a non-zero value in the flattened (1, 2) array
            # advantage of action = reward + ()
            # td error delta in () is a good estimator of advantage
            advantages[0] = reward - Svalue  # because discount * next_Svalue = 0
            target[0][0] = reward
            # subtract from last 3 moves leading to error
            # nested loop
        else:
            advantages[0] = reward + (self.discount_factor * next_Svalue - Svalue)
            target[0][0] = reward + self.discount_factor * next_Svalue

        return target, advantages

    def train(self, state, action, reward, next_state, done, target, advantages):

        """Use predict method to get the current policy, use fit to train
        actor to get the new policy, then get new/old ratio and clip
        self.previous holds prob from before """

        """get the old aprob, action is already determined"""
        old_policy = self.actor.predict(state, batch_size=1).flatten()
        #use formula to get prob from tanh here: 
        #https://stats.stackexchange.com/questions/409758/converting-tanh-activation-output-to-a-probability/410135#410135
        old_aprob = (old_policy + 1)/2
        """use temp_actor to get new prob so we don't update the actual actor until
        we do the clip op"""
        curr_weights = self.actor.get_weights()
        self.temp_actor.set_weights(curr_weights)
        self.temp_actor.fit(state, advantages, epochs=1, verbose=0)
        new_policy = self.temp_actor.predict(state, batch_size=1).flatten()
        new_aprob = (new_policy + 1)/2

        ratio = new_aprob / old_aprob
        # scale = min(ratio * advantages, K.clip(ratio, 1 - self.epsilon, 1 + self.epsilon) * advantages)
        no_clip = ratio * advantages #surr1
        clipped = (np.clip(ratio, 1 - self.epsilon, 1 + self.epsilon) * old_action) * advantages

        self.actor.fit(state, np.minimum(no_clip, clipped), epochs=1, verbose=0)
       
        
        self.critic.fit(state, target, epochs=1, verbose=0)

# %%
if __name__ == "__main__":

    env = gym.make('Pendulum-v0')

    state_size = env.observation_space.shape[0]
    action_size = env.action_space.shape[0]
    agent = PPOAgent(state_size, action_size)

    scores, episodes, means, stds = [], [], [], []

    for episode in range(EPISODES):
        done = False
        score = 0
        mean, std, large = 0, 0, 0
        state = env.reset()
        state = np.reshape(state, [1, state_size])

        while not done:
            if agent.render:
                env.render()

            # get action via stochastic policy
            action = agent.actor_action(state)
            next_state, reward, done, info = env.step(action)
            next_state = np.reshape(next_state, [1, state_size])

            reward = reward if not done or score == 499 else -100

            target, advantages = agent.targets_and_adv(state, action, reward, next_state, done)

            agent.train(state, action, reward, next_state, done, target, advantages)

            score += reward
            state = next_state

            if done:

                # agent.update_target_models()
                score = score if score == 500.0 else score + 100
                scores.append(score)
                mean = np.mean(scores[-min(10, len(scores)):])
                means.append(mean)
                std = np.std(scores[-min(10, len(scores)):])
                stds.append(std)
                large = max(scores)
                episodes.append(episode)
                pylab.plot(episodes, scores, 'b')  # blue
                pylab.plot(episodes, means, 'g')
                pylab.plot(episodes, stds, 'r')
                pylab.savefig("./saved_graphs/ppo_pendulum.png")
                print('episode:', episode, 'score:', score, 'mean:', round(mean, 2), 'std:', round(std, 2), 'max:',
                      large)
                # if last 10 scores mean over 490
                if np.mean(scores[-min(10, len(scores)):]) > 490:
                    sys.exit()

        # save model
        if episode % 50 == 0:
            agent.actor.save_weights("./saved_models/my_ppo_pendulum_actor.h5")
            agent.critic.save_weights("./saved_models/my_ppo_pendulum_critic.h5")
# Out:
# WARNING:tensorflow:From /home/nobu/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                96
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 24)                96
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 24)                96
# _________________________________________________________________
# dense_7 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/nobu/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode: 0 score: -1080.3380492389572 mean: -1080.34 std: 0.0 max: -1080.3380492389572
# episode: 1 score: -1640.3335192881452 mean: -1360.34 std: 280.0 max: -1080.3380492389572
# episode: 2 score: -1562.4146641734978 mean: -1427.7 std: 247.67 max: -1080.3380492389572
# episode: 3 score: -1486.4138890776774 mean: -1442.38 std: 215.99 max: -1080.3380492389572
# episode: 4 score: -1045.2485500303603 mean: -1362.95 std: 250.11 max: -1045.2485500303603
# episode: 5 score: -1556.1764123795217 mean: -1395.15 std: 239.41 max: -1045.2485500303603
# episode: 6 score: -1551.3947537875777 mean: -1417.47 std: 228.29 max: -1045.2485500303603
# episode: 7 score: -1452.3088942252518 mean: -1421.83 std: 213.86 max: -1045.2485500303603
# /home/nobu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:114: RuntimeWarning: invalid value encountered in true_divide
# episode: 8 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 9 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 10 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 11 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 12 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 13 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 14 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 15 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 16 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 17 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 18 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 19 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 20 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 21 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 22 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 23 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 24 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 25 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 26 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 27 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 28 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 29 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 30 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 31 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 32 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 33 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 34 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 35 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 36 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 37 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 38 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 39 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 40 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 41 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 42 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 43 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 44 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 45 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 46 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 47 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 48 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 49 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 50 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 51 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 52 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 53 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 54 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 55 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 56 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 57 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 58 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 59 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 60 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 61 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 62 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 63 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 64 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 65 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 66 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 67 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 68 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 69 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 70 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 71 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 72 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 73 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 74 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 75 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 76 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 77 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 78 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 79 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 80 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 81 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 82 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 83 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 84 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 85 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 86 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 87 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 88 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 89 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 90 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 91 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 92 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 93 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 94 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 95 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 96 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 97 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 98 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 99 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 100 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 101 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 102 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 103 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 104 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 105 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 106 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 107 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 108 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 109 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 110 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 111 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 112 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 113 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 114 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 115 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 116 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 117 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 118 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 119 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 120 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 121 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 122 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 123 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 124 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 125 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 126 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 127 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 128 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 129 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 130 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 131 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 132 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 133 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 134 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 135 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 136 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 137 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 138 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 139 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 140 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 141 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 142 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 143 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 144 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 145 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 146 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 147 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 148 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 149 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 150 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 151 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 152 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 153 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 154 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 155 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 156 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 157 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 158 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 159 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 160 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 161 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 162 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 163 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 164 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 165 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 166 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 167 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 168 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 169 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 170 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 171 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 172 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 173 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 174 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 175 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 176 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 177 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 178 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 179 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 180 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 181 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 182 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 183 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 184 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 185 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 186 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 187 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 188 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 189 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 190 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 191 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 192 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 193 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 194 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 195 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 196 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 197 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 198 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 199 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 200 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 201 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 202 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 203 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 204 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 205 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 206 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 207 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 208 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 209 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 210 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 211 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 212 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 213 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 214 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 215 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 216 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 217 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 218 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 219 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 220 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 221 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 222 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 223 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 224 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 225 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 226 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 227 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 228 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 229 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 230 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 231 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 232 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 233 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 234 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 235 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 236 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 237 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 238 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 239 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 240 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 241 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 242 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 243 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 244 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 245 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 246 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 247 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 248 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 249 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 250 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 251 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 252 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 253 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 254 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 255 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 256 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 257 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 258 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 259 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 260 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 261 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 262 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 263 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 264 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 265 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 266 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 267 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 268 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 269 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 270 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 271 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 272 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 273 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 274 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 275 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 276 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 277 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 278 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 279 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 280 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 281 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 282 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 283 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 284 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 285 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 286 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 287 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 288 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 289 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 290 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 291 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 292 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 293 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 294 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 295 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 296 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 297 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 298 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 299 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 300 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 301 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 302 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 303 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 304 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 305 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 306 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 307 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 308 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 309 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 310 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 311 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 312 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 313 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 314 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 315 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 316 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 317 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 318 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 319 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 320 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 321 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 322 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 323 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 324 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 325 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 326 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 327 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 328 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 329 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 330 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 331 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 332 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 333 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 334 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 335 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 336 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 337 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 338 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 339 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 340 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 341 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 342 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 343 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 344 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 345 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 346 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 347 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 348 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 349 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 350 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 351 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 352 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 353 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 354 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 355 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 356 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 357 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 358 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 359 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 360 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 361 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 362 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 363 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 364 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 365 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 366 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 367 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 368 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 369 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 370 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 371 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 372 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 373 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 374 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 375 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 376 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 377 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 378 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 379 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 380 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 381 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 382 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 383 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 384 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 385 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 386 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 387 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 388 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 389 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 390 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 391 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 392 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 393 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 394 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 395 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 396 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 397 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 398 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 399 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 400 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 401 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 402 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 403 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 404 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 405 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 406 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 407 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 408 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 409 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 410 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 411 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 412 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 413 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 414 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 415 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 416 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 417 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 418 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 419 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 420 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 421 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 422 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 423 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 424 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 425 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 426 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 427 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 428 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 429 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 430 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 431 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 432 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 433 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 434 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 435 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 436 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 437 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 438 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 439 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 440 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 441 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 442 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 443 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 444 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 445 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 446 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 447 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 448 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 449 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 450 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 451 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 452 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 453 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 454 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 455 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 456 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 457 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 458 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 459 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 460 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 461 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 462 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 463 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 464 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 465 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 466 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 467 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 468 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 469 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 470 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 471 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 472 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 473 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 474 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 475 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 476 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 477 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 478 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 479 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 480 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 481 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 482 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 483 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 484 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 485 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 486 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 487 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 488 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 489 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 490 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 491 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 492 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 493 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 494 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 495 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 496 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 497 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 498 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 499 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 500 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 501 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 502 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 503 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 504 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 505 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 506 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 507 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 508 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 509 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 510 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 511 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 512 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 513 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 514 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 515 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 516 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 517 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 518 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 519 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 520 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 521 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 522 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 523 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 524 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 525 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 526 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 527 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 528 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 529 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 530 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 531 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 532 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 533 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 534 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 535 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 536 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 537 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 538 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 539 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 540 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 541 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 542 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 543 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 544 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 545 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 546 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 547 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 548 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 549 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 550 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 551 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 552 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 553 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 554 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 555 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 556 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 557 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 558 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 559 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 560 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 561 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 562 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 563 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 564 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 565 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 566 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 567 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 568 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 569 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 570 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 571 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 572 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 573 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 574 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 575 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 576 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 577 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 578 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 579 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 580 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 581 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 582 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 583 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 584 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 585 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 586 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 587 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 588 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 589 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 590 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 591 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 592 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 593 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 594 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 595 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 596 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 597 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 598 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 599 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 600 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 601 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 602 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 603 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 604 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 605 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 606 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 607 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 608 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 609 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 610 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 611 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 612 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 613 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 614 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 615 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 616 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 617 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 618 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 619 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 620 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 621 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 622 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 623 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 624 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 625 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 626 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 627 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 628 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 629 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 630 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 631 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 632 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 633 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 634 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 635 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 636 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 637 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 638 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 639 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 640 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 641 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 642 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 643 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 644 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 645 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 646 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 647 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 648 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 649 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 650 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 651 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 652 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 653 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 654 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 655 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 656 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 657 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 658 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 659 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 660 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 661 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 662 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 663 score: nan mean: nan std: nan max: -1045.2485500303603
# ...
# episode: 765 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 766 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 767 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 768 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 769 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 770 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 771 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 772 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 773 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 774 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 775 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 776 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 777 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 778 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 779 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 780 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 781 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 782 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 783 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 784 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 785 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 786 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 787 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 788 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 789 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 790 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 791 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 792 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 793 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 794 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 795 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 796 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 797 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 798 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 799 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 800 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 801 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 802 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 803 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 804 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 805 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 806 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 807 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 808 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 809 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 810 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 811 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 812 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 813 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 814 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 815 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 816 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 817 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 818 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 819 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 820 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 821 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 822 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 823 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 824 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 825 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 826 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 827 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 828 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 829 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 830 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 831 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 832 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 833 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 834 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 835 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 836 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 837 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 838 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 839 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 840 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 841 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 842 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 843 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 844 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 845 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 846 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 847 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 848 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 849 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 850 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 851 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 852 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 853 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 854 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 855 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 856 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 857 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 858 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 859 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 860 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 861 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 862 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 863 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 864 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 865 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 866 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 867 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 868 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 869 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 870 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 871 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 872 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 873 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 874 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 875 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 876 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 877 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 878 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 879 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 880 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 881 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 882 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 883 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 884 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 885 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 886 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 887 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 888 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 889 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 890 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 891 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 892 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 893 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 894 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 895 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 896 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 897 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 898 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 899 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 900 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 901 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 902 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 903 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 904 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 905 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 906 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 907 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 908 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 909 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 910 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 911 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 912 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 913 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 914 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 915 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 916 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 917 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 918 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 919 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 920 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 921 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 922 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 923 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 924 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 925 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 926 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 927 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 928 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 929 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 930 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 931 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 932 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 933 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 934 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 935 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 936 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 937 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 938 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 939 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 940 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 941 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 942 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 943 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 944 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 945 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 946 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 947 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 948 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 949 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 950 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 951 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 952 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 953 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 954 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 955 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 956 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 957 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 958 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 959 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 960 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 961 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 962 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 963 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 964 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 965 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 966 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 967 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 968 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 969 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 970 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 971 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 972 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 973 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 974 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 975 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 976 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 977 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 978 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 979 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 980 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 981 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 982 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 983 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 984 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 985 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 986 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 987 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 988 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 989 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 990 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 991 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 992 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 993 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 994 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 995 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 996 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 997 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 998 score: nan mean: nan std: nan max: -1045.2485500303603
# episode: 999 score: nan mean: nan std: nan max: -1045.2485500303603
